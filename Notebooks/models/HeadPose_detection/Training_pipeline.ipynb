# %% [markdown]
# ## Setup

# %% [markdown]
# ## download datasets to locaRankPose/data/
# * https://drive.google.com/file/d/0B7OEHD3T4eCkVGs0TkhUWFN6N1k/view?usp=sharing

# %%
# %%bash
# git clone https://github.com/seathiefwang/RankPose.git
# Out:
# Cloning into 'RankPose'...

# %%
# %%bash
# cd RankPose
# CUDA_VISIBLE_DEVICES=0 python3 src/train.py config/headpose_resnet.yaml
